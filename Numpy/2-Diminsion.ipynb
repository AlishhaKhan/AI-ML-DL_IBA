# %% [markdown]
# **1D vs 2D**

# %% [markdown]
# 1D = list jaisa
#
# 2D = table jaisa (rows + columns)
#
# *Usage*
#
# 1D = simple values store karne ke liye, marks list, prices list
#
# 2D = datasets, excel sheets, pandas dataframe, ML model input

# %% [markdown]
# *Create a 2D Numpy Array*

# %%
import numpy as np

# %% [markdown]
# Consider the list a , the list contains three nested lists each of equal size.

# %%
# Create a list
Lst2 = [[11, 12, 13],
[21, 22, 23],
[31, 32, 33]]
Lst2
# Out:
# [[11, 12, 13], [21, 22, 23], [31, 32, 33]]

# %% [markdown]
# *Convert list to Numpy Array*

# %% [markdown]
# Every element is the same type

# %%
Ar = np.array(Lst2)
Ar
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])

# %% [markdown]
# *Show the numpy array dimensions*

# %% [markdown]
# We can use the attribute ndim to obtain the number of axes or dimensions referred to as the
# rank.

# %%
Ar.ndim
# Out:
# 2

# %% [markdown]
# *Show the numpy array shape*

# %% [markdown]
# Attribute shape returns a tuple corresponding to the size or number of each dimension.

# %%
Ar.shape
# Out:
# (3, 3)

# %% [markdown]
# *Show the numpy array size*

# %% [markdown]
# The total number of elements in the array is given by the attribute size .

# %%
Ar.size
# Out:
# 9

# %% [markdown]
# *Accessing different elements of a Numpy Array*

# %% [markdown]
# We can use rectangular brackets to access the different elements of the array. The
# correspondence between the rectangular brackets and the list and the rectangular representation
# is shown in the following figure for a 3x3 array:
#
# [A[0,0] A[0,1] A[0,2]
#
#  A[1,0] A[1,1] A[1,2]
#
#  A[2,0] A[2,1] A[2,2]]

# %% [markdown]
# *Access the element*
#
# We simply use the square brackets and the indices corresponding to the element we would like:
#
# [11 12 13
#
#  21 22 23
#
#  31 32 33]

# %%
Ar[1, 2] # [row, column]
# Out:
# np.int64(23)

# %% [markdown]
# We can also use the following notation to obtain the elements:

# %%
# Access the element on the first row and first column
Ar[0][0] # [row][column]
# Out:
# np.int64(11)

# %% [markdown]
# We can also use slicing in numpy arrays. Consider the following figure. We would like to obtain
# the first two columns in the first row

# %%
# Access the element on the 1st row and 1st and 2nd columns
Ar[0][0:2] # [row][start:stop+1]
# Out:
# array([11, 12])

# %% [markdown]
# Similarly, we can obtain the 2nd and 3rd rows of the 3rd column as follows:

# %%
# Access the element on the 2nd and 3rd rows and 3rd column
Ar[1:3, 2] # [start:stop+1][column]
# Out:
# array([23, 33])

# %% [markdown]
# *Basic Operations*

# %% [markdown]
# We can also add arrays. The process is identical to matrix addition. Matrix addition of X and Y
# is shown in the following figure:

# %%
# Create a numpy array X and Y
X = np.array([[1, 0],
              [0, 1]])
print("X =")
print(X)

Y =np.array([[2,1],
             [1,2]])
print("Y =")
print(Y)
# Out:
# X =
# [[1 0]
#  [0 1]]
# Y =
# [[2 1]
#  [1 2]]

# %% [markdown]
# We can add numpy arrays as follow

# %%
# add X and Y
Z = X + Y
Z
# Out:
# array([[3, 1],
#        [1, 3]])

# %% [markdown]
# Multiplying a numpy array by a scaler is identical to multiplying a matrix by a scaler. If we multiply the matrix Y by the scaler 2, we simply multiply every element in the matrix by 2 as shown in the figure.

# %%
# create a numpy array Y
Y = np.array([[2,1],
              [1,2]])
Y
# Out:
# array([[2, 1],
#        [1, 2]])

# %%
# multiply Y with 2
Z = Y * 2
Z
# Out:
# array([[4, 2],
#        [2, 4]])

# %% [markdown]
# Multiplication of two arrays corresponds to an element-wise product or Hadamard product. Consider matrix X and Y. The Hadamard product correspond to multiplying each of the elements in the same position, i.e multiplying element contained in the same color boxes together. The result is a new matrix that is the same size as matrix Y or X.

# %%
# create a numpy array Y
Y = np.array([[2,1],
              [1,2]])
Y
# Out:
# array([[2, 1],
#        [1, 2]])

# %%
# create a numpy array X
X = np.array([[1,0],
              [0,1]])
X
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
# multiply X * Y
Z = X * Y
Z
# Out:
# array([[2, 0],
#        [0, 2]])

# %% [markdown]
# We can also perform the matrix multiplication as follow

# %%
# Create a matrix A
A = np.array([[0, 1, 1],
[1, 0, 1]]) # 2 x 3 Matix
A
# Out:
# array([[0, 1, 1],
#        [1, 0, 1]])

# %%
# Create a matrix B
B = np.array([[1, 1],
[1, 1],
[-1, 1]]) # 3 x 2 Matrix
B
# Out:
# array([[ 1,  1],
#        [ 1,  1],
#        [-1,  1]])

# %% [markdown]
# We use the numpy function dot to multiply the arrays together.

# %%
# Calculate the dot product
Z = np.dot(A,B)
Z
# Out:
# array([[0, 2],
#        [0, 2]])

# %% [markdown]
# We use the numpy attribute T to calculate the transposed matrix

# %%
# Create a matrix C
C = np.array([[1,1],
[2,2],
[3,3]])
C
# Out:
# array([[1, 1],
#        [2, 2],
#        [3, 3]])

# %%
# Get the transposed of C
C.T
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])
