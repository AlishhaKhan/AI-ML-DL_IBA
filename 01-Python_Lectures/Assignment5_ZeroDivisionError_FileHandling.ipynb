# %% [markdown]
# **14. ZeroDivisionError (try/except)**

# %% [markdown]
# Used to handled errors safely when a number is divided by zero, preventing program crash.
#
# example:
#
#        try:
#
#        x = 10/0
#
#        except ZeroDivisionError:
#
#        print("Cannot divide by Zero")

# %%
n1 = input("Enter 1st Number: ")
n2 = input("Enter 2nd Number: ")
def div(a, b):
 res = float(a) / float(b)
 return res
c = div(n1, n2)
print(f"Result of {n1} / {n2} is: {c}")
# Out:
# Enter 1st Number: 4.0
# Enter 2nd Number: 2.0
# Result of 4.0 / 2.0 is: 2.0

# %% [markdown]
# *ZeroDivisionError*

# %%
n1 = input("Enter 1st Number: ")
n2 = input("Enter 2nd Number: ")
def div(a, b):
 res = float(a) / float(b)
 return res
c = div(n1, n2)
print(f"Result of {n1} / {n2} is: {c}")
# Out:
# Enter 1st Number: 0
# Enter 2nd Number: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_5795/4153249188.py in <cell line: 0>()
#       4  res = float(a) / float(b)
#       5  return res
# ----> 6 c = div(n1, n2)
#       7 print(f"Result of {n1} / {n2} is: {c}")
#
# /tmp/ipykernel_5795/4153249188.py in div(a, b)
#       2 n2 = input("Enter 2nd Number: ")
#       3 def div(a, b):
# ----> 4  res = float(a) / float(b)
#       5  return res
#       6 c = div(n1, n2)
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# *try & except*

# %%
n1 = input("Enter 1st Number: ")
n2 = input("Enter 2nd Number: ")

def div(a, b):
 try:
  res = float(a) / float(b)
 except:
  res = "Can't divide with zero"
 return res
c = div(n1, n2)
print(f"Result of {n1} / {n2} is: {c}")
# Out:
# Enter 1st Number: 8
# Enter 2nd Number: 0
# Result of 8 / 0 is: Can't divide with zero

# %%
n1 = input("Enter 1st Number: ")
n2 = input("Enter 2nd Number: ")

def div(a, b):
 try:
  res = float(a) / float(b)
 except:
  res = "Can't divide with zero"
 return res
c = div(n1, n2)
print(f"Result of {n1} / {n2} is: {c}")
# Out:
# Enter 1st Number: 8
# Enter 2nd Number: 4
# Result of 8 / 4 is: 2.0

# %% [markdown]
# *try, except & finally*

# %%
n1 = input("Enter 1st Number: ")
n2 = input("Enter 2nd Number: ")
def div(a, b):
 try:
  res = float(a) / float(b)
 except:
  res = "Can't divide with zero"
 finally:
  return res
c = div(n1, n2)
print(f"Result of {n1} / {n2} is: {c}")
# Out:
# Enter 1st Number: 6
# Enter 2nd Number: 2
# Result of 6 / 2 is: 3.0

# %%
n1 = input("Enter 1st Number: ")
n2 = input("Enter 2nd Number: ")
def div(a, b):
 try:
  res = float(a) / float(b)
 except:
  res = "Can't divide with zero"
 finally:
  return res
c = div(n1, n2)
print(f"Result of {n1} / {n2} is: {c}")
# Out:
# Enter 1st Number: 6
# Enter 2nd Number: 0
# Result of 6 / 0 is: Can't divide with zero

# %% [markdown]
# 🔥Pro Tip (exam/quiz ke liye)
#
#  try → risky code
#
#  except → error handle
#
#  else → no error case
#
#  finally → always run

# %% [markdown]
# **File Handling**

# %% [markdown]
# **Read Only (‘r’):** Open text file for reading. The handle is positioned at the beginning of the file. If
# the file does not exists, raises I/O error. This is also the default mode in which file is opened.

# %% [markdown]
# **Read and Write (‘r+’):** Open the file for reading and writing. The handle is positioned at the
# beginning of the file. Raises I/O error if the file does not exists.

# %% [markdown]
# **Write Only (‘w’):** Open the file for writing. For existing file, the data is truncated and over-written.
# The handle is positioned at the beginning of the file. Creates the file if the file does not exists.

# %% [markdown]
# **Write and Read (‘w+’):** Open the file for reading and writing. For existing file, data is truncated and
# over-written. The handle is positioned at the beginning of the file.

# %% [markdown]
# **Append Only (‘a’):** Open the file for writing. The file is created if it does not exist. The handle is
# positioned at the end of the file. The data being written will be inserted at the end, after the existing
# data.

# %% [markdown]
# **Append and Read (‘a+’):** Open the file for reading and writing. The file is created if it does not
# exist. The handle is positioned at the end of the file. The data being written will be inserted at the
# end, after the existing data.

# %% [markdown]
# *Create a File*

# %%
FileNm = "pyFile.txt"
File = open(FileNm, "w+")

# %% [markdown]
# *Get File Info*

# %%
print("Name of the file: ", File.name)
print("Closed or not : ", File.closed)
print("Opening mode : ", File.mode)
# Out:
# Name of the file:  pyFile.txt
# Closed or not :  False
# Opening mode :  w+

# %% [markdown]
# *Close File*

# %%
File.close()
print("Closed or not : ", File.closed)
# Out:
# Closed or not :  True

# %% [markdown]
# *Write Text to the File*

# %%
# Open a file
File = open(FileNm, "w")
File.write("Python: Write text to File"+ '\n')
File.close()

# %%
File = open(FileNm, "r")
str = File.read()
str
# Out:
# 'Python: Write text to File\n'

# %%
print(str)
# Out:
# Python: Write text to File

# %% [markdown]
# *Append a file*

# %%
# Open a file
File = open(FileNm, "a+")
File.write( "Python: 2nd line to the File"+ '\n')
# Out:
# 29

# %%
File = open(FileNm, "r+")
str = File.read(50) # number of bytes
print(str)
# Out:
# Python: Write text to File
# Python: 2nd line to the

# %%
File = open(FileNm, "r+")
str = File.read()
print(str)
# Out:
# Python: Write text to File
# Python: 2nd line to the File

# %% [markdown]
# *Writelines*

# %%
File = open(FileNm, "a+")
File.writelines("Python: 3rd line to the File"+ '\n')

# %%
File = open(FileNm, "r+")
str = File.read()
print(str)
# Out:
# Python: Write text to File
# Python: 2nd line to the File
# Python: 3rd line to the File

# %% [markdown]
# *Readlines*

# %%
File = open(FileNm, "r+")
str = File.readline()
print(str)
# Out:
# Python: Write text to File

# %%
File = open(FileNm, "r+")
str = File.readlines()
print(str)
# Out:
# ['Python: Write text to File\n', 'Python: 2nd line to the File\n', 'Python: 3rd line to the File\n']

# %% [markdown]
# *Write multiple lines*

# %%
with open(FileNm, "a+") as f:
 for line in range(4, 7):
  f.write(f"Python: line # {line} to the File" + '\n')

# %%
File = open(FileNm, "r+")
str = File.read()
print(str)
# Out:
# Python: Write text to File
# Python: 2nd line to the File
# Python: 3rd line to the File
# Python: line # 4 to the File
# Python: line # 5 to the File
# Python: line # 6 to the File

# %% [markdown]
# *Write line using a method*

# %%
def Write2File(file, lines):
 with open(file, "a+") as f:
  for line in lines:
   f.write(line + '\n')

# %%
Lines = ["The sun sets over the horizon.", "Birds chirp in the morning.", "Raindrops patte"]

# %%
Write2File(FileNm, Lines)

# %%
File = open(FileNm, "r+")
str = File.read()
print(str)
# Out:
# Python: Write text to File
# Python: 2nd line to the File
# Python: 3rd line to the File
# Python: line # 4 to the File
# Python: line # 5 to the File
# Python: line # 6 to the File
# The sun sets over the horizon.
# Birds chirp in the morning.
# Raindrops patte
